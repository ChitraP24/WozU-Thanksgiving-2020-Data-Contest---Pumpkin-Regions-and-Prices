# %% [markdown]
# # Chitra Patel -> Thanksgiving Contest 2020

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Importing Datasets

# %%
West = pd.read_excel('West_Region.xlsx')
West.head()
# Out:
#   Commodity.Name      City.Name       Package      Variety        Date  \
# 0       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  09/24/2016
# 1       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/01/2016
# 2       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/01/2016
# 3       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/01/2016
# 4       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/08/2016
#
#    Low.Price  High.Price      Origin Item.Size Color
# 0      155.0       155.0  CALIFORNIA       NaN   NaN
# 1      155.0       155.0  CALIFORNIA       NaN   NaN
# 2      155.0       155.0  CALIFORNIA       lge   NaN
# 3      135.0       135.0  CALIFORNIA       sml   NaN
# 4      135.0       150.0  CALIFORNIA       lge   NaN

# %%
East = pd.read_excel('East_Region.xlsx')
East.head()
# Out:
#   Commodity.Name City.Name       Package      Variety        Date  Low.Price  \
# 0       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        150
# 1       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        150
# 2       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        130
# 3       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        130
# 4       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        120
#
#    High.Price      Origin Item.Size Color
# 0       170.0    MICHIGAN      xlge   NaN
# 1       170.0    MICHIGAN       lge   NaN
# 2       150.0  NEW JERSEY      xlge   NaN
# 3       150.0  NEW JERSEY       lge   NaN
# 4       140.0    NEW YORK   med-lge   NaN

# %% [markdown]
# # Data Wrangling
# ## Recoding variables from string to integer

# %%
def recode (series):
    if series == "sml":
        return 1
    if series == "med":
        return 2
    if series == "lge":
        return 3
    if series == "xlge":
        return 4
    if series == "jbo":
        return 5
    if series == "med-lge":
        return 6
    if series == "exjbo":
        return 7
    
West['ItemSizeR'] = West['Item.Size'].apply(recode)

# %%
West.head()
# Out:
#   Commodity.Name      City.Name       Package      Variety        Date  \
# 0       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  09/24/2016
# 1       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/01/2016
# 2       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/01/2016
# 3       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/01/2016
# 4       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/08/2016
#
#    Low.Price  High.Price      Origin Item.Size Color  ItemSizeR
# 0      155.0       155.0  CALIFORNIA       NaN   NaN        NaN
# 1      155.0       155.0  CALIFORNIA       NaN   NaN        NaN
# 2      155.0       155.0  CALIFORNIA       lge   NaN        3.0
# 3      135.0       135.0  CALIFORNIA       sml   NaN        1.0
# 4      135.0       150.0  CALIFORNIA       lge   NaN        3.0

# %%
def recode (series):
    if series == "HOWDEN TYPE":
        return 1
    if series == "CINDERELLA":
        return 2
    if series == "FAIRYTALE":
        return 3
    if series == "PIE TYPE":
        return 4
    if series == "BLUE TYPE":
        return 5
    if series == "BIG MACK TYPE":
        return 6
    if series == "MIXED HEIRLOOM VARIETIES":
        return 7
    if series == "KNUCKLE HEAD":
        return 10
    if series == "MINIATURE":
        return 11
    if series == "HOWDEN WHITE TYPE":
        return 12
    
West['VarietyR'] = West['Variety'].apply(recode)

# %%
West.head()
# Out:
#   Commodity.Name      City.Name       Package      Variety        Date  \
# 0       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  09/24/2016
# 1       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/01/2016
# 2       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/01/2016
# 3       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/01/2016
# 4       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/08/2016
#
#    Low.Price  High.Price      Origin Item.Size Color  ItemSizeR  VarietyR
# 0      155.0       155.0  CALIFORNIA       NaN   NaN        NaN         1
# 1      155.0       155.0  CALIFORNIA       NaN   NaN        NaN         1
# 2      155.0       155.0  CALIFORNIA       lge   NaN        3.0         1
# 3      135.0       135.0  CALIFORNIA       sml   NaN        1.0         1
# 4      135.0       150.0  CALIFORNIA       lge   NaN        3.0         1

# %%
West.drop(['Variety', 'Item.Size'], axis=1, inplace=True)

# %%
West.head()
# Out:
#   Commodity.Name      City.Name       Package        Date  Low.Price  \
# 0       PUMPKINS  SAN FRANCISCO  24 inch bins  09/24/2016      155.0
# 1       PUMPKINS  SAN FRANCISCO  24 inch bins  10/01/2016      155.0
# 2       PUMPKINS  SAN FRANCISCO  24 inch bins  10/01/2016      155.0
# 3       PUMPKINS  SAN FRANCISCO  24 inch bins  10/01/2016      135.0
# 4       PUMPKINS  SAN FRANCISCO  24 inch bins  10/08/2016      135.0
#
#    High.Price      Origin Color  ItemSizeR  VarietyR
# 0       155.0  CALIFORNIA   NaN        NaN         1
# 1       155.0  CALIFORNIA   NaN        NaN         1
# 2       155.0  CALIFORNIA   NaN        3.0         1
# 3       135.0  CALIFORNIA   NaN        1.0         1
# 4       150.0  CALIFORNIA   NaN        3.0         1

# %%
def recode (series):
    if series == "sml":
        return 1
    if series == "med":
        return 2
    if series == "lge":
        return 3
    if series == "xlge":
        return 4
    if series == "jbo":
        return 5
    if series == "med-lge":
        return 6
    if series == "exjbo":
        return 7
    
East['ItemSizeR'] = East['Item.Size'].apply(recode)

# %%
East.head()
# Out:
#   Commodity.Name City.Name       Package      Variety        Date  Low.Price  \
# 0       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        150
# 1       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        150
# 2       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        130
# 3       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        130
# 4       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        120
#
#    High.Price      Origin Item.Size Color  ItemSizeR
# 0       170.0    MICHIGAN      xlge   NaN        4.0
# 1       170.0    MICHIGAN       lge   NaN        3.0
# 2       150.0  NEW JERSEY      xlge   NaN        4.0
# 3       150.0  NEW JERSEY       lge   NaN        3.0
# 4       140.0    NEW YORK   med-lge   NaN        6.0

# %%
def recode (series):
    if series == "HOWDEN TYPE":
        return 1
    if series == "CINDERELLA":
        return 2
    if series == "FAIRYTALE":
        return 3
    if series == "PIE TYPE":
        return 4
    if series == "BLUE TYPE":
        return 5
    if series == "BIG MACK TYPE":
        return 6
    if series == "MIXED HEIRLOOM VARIETIES":
        return 7
    if series == "KNUCKLE HEAD":
        return 10
    if series == "MINIATURE":
        return 11
    if series == "HOWDEN WHITE TYPE":
        return 12
    
East['VarietyR'] = East['Variety'].apply(recode)

# %%
East.head()
# Out:
#   Commodity.Name City.Name       Package      Variety        Date  Low.Price  \
# 0       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        150
# 1       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        150
# 2       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        130
# 3       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        130
# 4       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        120
#
#    High.Price      Origin Item.Size Color  ItemSizeR  VarietyR
# 0       170.0    MICHIGAN      xlge   NaN        4.0       1.0
# 1       170.0    MICHIGAN       lge   NaN        3.0       1.0
# 2       150.0  NEW JERSEY      xlge   NaN        4.0       1.0
# 3       150.0  NEW JERSEY       lge   NaN        3.0       1.0
# 4       140.0    NEW YORK   med-lge   NaN        6.0       1.0

# %% [markdown]
# ### Export without dropping any columns

# %%
West.to_excel('West_Region4.xlsx')

# %%
East.to_excel('East_Region4.xlsx')

# %% [markdown]
# ____

# %%
East.drop(['Variety', 'Item.Size'], axis=1, inplace=True)

# %%
East.head()
# Out:
#   Commodity.Name City.Name       Package        Date  Low.Price  High.Price  \
# 0       PUMPKINS  NEW YORK  36 inch bins  09/24/2016        150       170.0
# 1       PUMPKINS  NEW YORK  36 inch bins  09/24/2016        150       170.0
# 2       PUMPKINS  NEW YORK  36 inch bins  09/24/2016        130       150.0
# 3       PUMPKINS  NEW YORK  36 inch bins  09/24/2016        130       150.0
# 4       PUMPKINS  NEW YORK  36 inch bins  09/24/2016        120       140.0
#
#        Origin Color  ItemSizeR  VarietyR
# 0    MICHIGAN   NaN        4.0       1.0
# 1    MICHIGAN   NaN        3.0       1.0
# 2  NEW JERSEY   NaN        4.0       1.0
# 3  NEW JERSEY   NaN        3.0       1.0
# 4    NEW YORK   NaN        6.0       1.0

# %%
East['Origin'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          MICHIGAN
# 1          MICHIGAN
# 2        NEW JERSEY
# 3        NEW JERSEY
# 4          NEW YORK
#            ...
# 669        MARYLAND
# 670    PENNSYLVANIA
# 671        MARYLAND
# 672        MARYLAND
# 673        MARYLAND
# Name: Origin, Length: 674, dtype: object>

# %% [markdown]
# # Export files to Excel

# %%
West.to_excel('West_Region2.xlsx')

# %%
East.to_excel('East_Region2.xlsx')

# %% [markdown]
# _____

# %%
## Recoding Origin

# %%
def recode (series):
    if series == "CALIFORNIA":
        return 1
    if series == "WASHINGTON":
        return 2
    
    
West['OriginR'] = West['Origin'].apply(recode)

# %%
West.head()
# Out:
#   Commodity.Name      City.Name       Package      Variety        Date  \
# 0       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  09/24/2016
# 1       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/01/2016
# 2       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/01/2016
# 3       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/01/2016
# 4       PUMPKINS  SAN FRANCISCO  24 inch bins  HOWDEN TYPE  10/08/2016
#
#    Low.Price  High.Price      Origin Item.Size Color  ItemSizeR  VarietyR  \
# 0      155.0       155.0  CALIFORNIA       NaN   NaN        NaN         1
# 1      155.0       155.0  CALIFORNIA       NaN   NaN        NaN         1
# 2      155.0       155.0  CALIFORNIA       lge   NaN        3.0         1
# 3      135.0       135.0  CALIFORNIA       sml   NaN        1.0         1
# 4      135.0       150.0  CALIFORNIA       lge   NaN        3.0         1
#
#    OriginR
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
West.drop(['Origin'], axis=1, inplace=True)

# %%
West.head()
# Out:
#   Commodity.Name      City.Name       Package        Date  Low.Price  \
# 0       PUMPKINS  SAN FRANCISCO  24 inch bins  09/24/2016      155.0
# 1       PUMPKINS  SAN FRANCISCO  24 inch bins  10/01/2016      155.0
# 2       PUMPKINS  SAN FRANCISCO  24 inch bins  10/01/2016      155.0
# 3       PUMPKINS  SAN FRANCISCO  24 inch bins  10/01/2016      135.0
# 4       PUMPKINS  SAN FRANCISCO  24 inch bins  10/08/2016      135.0
#
#    High.Price Color  ItemSizeR  VarietyR  OriginR
# 0       155.0   NaN        NaN         1        1
# 1       155.0   NaN        NaN         1        1
# 2       155.0   NaN        3.0         1        1
# 3       135.0   NaN        1.0         1        1
# 4       150.0   NaN        3.0         1        1

# %%
 def recode (series):
    if series == "DELAWARE":
        return 1
    if series == "MICHIGAN":
        return 2
    if series == "NEW JERSEY":
        return 3
    if series == "NEW YORK":
        return 4
    if series == "OHIO":
        return 5
    if series == "PENNSYLVANIA":
        return 6
    if series == "COSTA RICA":
        return 7
    if series == "FLORIDA":
        return 8
    if series == "MARYLAND":
        return 9
    if series == "MEXICO":
        return 10
    if series == "VIRGINIA":
        return 11
    if series == "CANADA":
        return 12
    if series == "MASSACHUSETTS":
        return 13
    if series == "VERMONT":
        return 14
        
East['OriginR'] = East['Origin'].apply(recode)

# %%
East.head()
# Out:
#   Commodity.Name City.Name       Package      Variety        Date  Low.Price  \
# 0       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        150
# 1       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        150
# 2       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        130
# 3       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        130
# 4       PUMPKINS  NEW YORK  36 inch bins  HOWDEN TYPE  09/24/2016        120
#
#    High.Price      Origin Item.Size Color  ItemSizeR  VarietyR  OriginR
# 0       170.0    MICHIGAN      xlge   NaN        4.0       1.0      2.0
# 1       170.0    MICHIGAN       lge   NaN        3.0       1.0      2.0
# 2       150.0  NEW JERSEY      xlge   NaN        4.0       1.0      3.0
# 3       150.0  NEW JERSEY       lge   NaN        3.0       1.0      3.0
# 4       140.0    NEW YORK   med-lge   NaN        6.0       1.0      4.0

# %%
East.drop(['Origin'], axis=1, inplace=True)

# %%
East.head()
# Out:
#   Commodity.Name City.Name       Package        Date  Low.Price  High.Price  \
# 0       PUMPKINS  NEW YORK  36 inch bins  09/24/2016        150       170.0
# 1       PUMPKINS  NEW YORK  36 inch bins  09/24/2016        150       170.0
# 2       PUMPKINS  NEW YORK  36 inch bins  09/24/2016        130       150.0
# 3       PUMPKINS  NEW YORK  36 inch bins  09/24/2016        130       150.0
# 4       PUMPKINS  NEW YORK  36 inch bins  09/24/2016        120       140.0
#
#   Color  ItemSizeR  VarietyR  OriginR
# 0   NaN        4.0       1.0      2.0
# 1   NaN        3.0       1.0      2.0
# 2   NaN        4.0       1.0      3.0
# 3   NaN        3.0       1.0      3.0
# 4   NaN        6.0       1.0      4.0

# %%
East.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_e0dce4dc_3aa9_11eb_8af9_406c8f4f26a8row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e0dce4dc_3aa9_11eb_8af9_406c8f4f26a8row0_col1 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_e0dce4dc_3aa9_11eb_8af9_406c8f4f26a8row0_col2 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_e0dce4dc_3aa9_11eb_8af9_406c8f4f26a8row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e0dce4dc_3aa9_11eb_8af9_406c8f4f26a8row0_col4 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_e0dce4dc_3aa9_11eb_8af9_406c8f4f26a8row1_col0 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_e0dce4dc_3aa9_11eb_8af9_406c8f4f26a8row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
# ...

# %%
West.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_e0e7b600_3aa9_11eb_8af9_406c8f4f26a8row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e0e7b600_3aa9_11eb_8af9_406c8f4f26a8row0_col1 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_e0e7b600_3aa9_11eb_8af9_406c8f4f26a8row0_col2 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_e0e7b600_3aa9_11eb_8af9_406c8f4f26a8row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e0e7b600_3aa9_11eb_8af9_406c8f4f26a8row0_col4 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_e0e7b600_3aa9_11eb_8af9_406c8f4f26a8row1_col0 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_e0e7b600_3aa9_11eb_8af9_406c8f4f26a8row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
# ...
