# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Import Data

# %%
SRPumpkins = pd.read_csv('C:\South_RegionPumpkins.csv')

# %%
SRPumpkins.head()
# Out:
#    Unnamed: 0 Commodity Name City Name       Package      Variety        Date  \
# 0           1       PUMPKINS    DALLAS  24 inch bins          NaN  09/16/2017
# 1           2       PUMPKINS    DALLAS  24 inch bins          NaN  09/23/2017
# 2           3       PUMPKINS    DALLAS  24 inch bins          NaN  09/30/2017
# 3           4       PUMPKINS    DALLAS  24 inch bins  HOWDEN TYPE  09/24/2016
# 4           5       PUMPKINS    DALLAS  24 inch bins  HOWDEN TYPE  09/24/2016
#
#    Low Price  High Price Origin Item Size Color
# 0      160.0       225.0  TEXAS       lge   NaN
# 1      160.0       225.0  TEXAS       lge   NaN
# 2      160.0       225.0  TEXAS       lge   NaN
# 3      160.0       160.0  TEXAS       jbo   NaN
# 4      150.0       150.0  TEXAS       med   NaN

# %%
MDWPumpkins = pd.read_csv('C:\Midwest_RegionPumpkins.csv')

# %%
MDWPumpkins.head()
# Out:
#    Unnamed: 0 Commodity Name City Name       Package      Variety        Date  \
# 0           1       PUMPKINS   DETROIT  24 inch bins  HOWDEN TYPE  09/16/2017
# 1           2       PUMPKINS   DETROIT  24 inch bins  HOWDEN TYPE  09/16/2017
# 2           3       PUMPKINS   DETROIT  24 inch bins  HOWDEN TYPE  09/23/2017
# 3           4       PUMPKINS   DETROIT  24 inch bins  HOWDEN TYPE  09/23/2017
# 4           5       PUMPKINS   DETROIT          bins  HOWDEN TYPE  09/23/2017
#
#    Low Price  High Price    Origin Item Size Color
# 0       95.0        95.0  MICHIGAN       lge   NaN
# 1       94.0        95.0  MICHIGAN       med   NaN
# 2       95.0        95.0  MICHIGAN       lge   NaN
# 3       94.0        95.0  MICHIGAN       med   NaN
# 4      175.0       175.0  MICHIGAN      xlge   NaN

# %% [markdown]
# # Data Wrangling

# %%
def recode (series):
    if series == "sml":
        return 1
    if series == "med":
        return 2
    if series == "lge":
        return 3
    if series == "xlge":
        return 4
    if series == "jbo":
        return 5
    if series == "med-lge":
        return 6
    if series == "exjbo":
        return 7

# %%
SRPumpkins['ItemSizeR']=SRPumpkins['Item Size'].apply(recode)

# %%
SRPumpkins.head()
# Out:
#    Unnamed: 0 Commodity Name City Name       Package      Variety        Date  \
# 0           1       PUMPKINS    DALLAS  24 inch bins          NaN  09/16/2017
# 1           2       PUMPKINS    DALLAS  24 inch bins          NaN  09/23/2017
# 2           3       PUMPKINS    DALLAS  24 inch bins          NaN  09/30/2017
# 3           4       PUMPKINS    DALLAS  24 inch bins  HOWDEN TYPE  09/24/2016
# 4           5       PUMPKINS    DALLAS  24 inch bins  HOWDEN TYPE  09/24/2016
#
#    Low Price  High Price Origin Item Size Color  ItemSizeR
# 0      160.0       225.0  TEXAS       lge   NaN        3.0
# 1      160.0       225.0  TEXAS       lge   NaN        3.0
# 2      160.0       225.0  TEXAS       lge   NaN        3.0
# 3      160.0       160.0  TEXAS       jbo   NaN        5.0
# 4      150.0       150.0  TEXAS       med   NaN        2.0

# %%
MDWPumpkins['ItemSizeR']=MDWPumpkins['Item Size'].apply(recode)

# %%
MDWPumpkins.head()
# Out:
#    Unnamed: 0 Commodity Name City Name       Package      Variety        Date  \
# 0           1       PUMPKINS   DETROIT  24 inch bins  HOWDEN TYPE  09/16/2017
# 1           2       PUMPKINS   DETROIT  24 inch bins  HOWDEN TYPE  09/16/2017
# 2           3       PUMPKINS   DETROIT  24 inch bins  HOWDEN TYPE  09/23/2017
# 3           4       PUMPKINS   DETROIT  24 inch bins  HOWDEN TYPE  09/23/2017
# 4           5       PUMPKINS   DETROIT          bins  HOWDEN TYPE  09/23/2017
#
#    Low Price  High Price    Origin Item Size Color  ItemSizeR
# 0       95.0        95.0  MICHIGAN       lge   NaN        3.0
# 1       94.0        95.0  MICHIGAN       med   NaN        2.0
# 2       95.0        95.0  MICHIGAN       lge   NaN        3.0
# 3       94.0        95.0  MICHIGAN       med   NaN        2.0
# 4      175.0       175.0  MICHIGAN      xlge   NaN        4.0

# %%
def recode (series):
    if series == "HOWDEN TYPE":
        return 1
    if series == "CINDERELLA":
        return 2
    if series == "FAIRYTALE":
        return 3
    if series == "PIE TYPE":
        return 4
    if series == "MIXED HEIRLOOM VARIETIES":
        return 7
    if series == "MINIATURE":
        return 11
    if series == "HOWDEN WHITE TYPE":
        return 12

# %%
SRPumpkins['VarietyR']=SRPumpkins['Variety'].apply(recode)

# %%
SRPumpkins.drop(['Variety','Item Size'], axis=1, inplace=True)

# %%
SRPumpkins.head()
# Out:
#    Unnamed: 0 Commodity Name City Name       Package        Date  Low Price  \
# 0           1       PUMPKINS    DALLAS  24 inch bins  09/16/2017      160.0
# 1           2       PUMPKINS    DALLAS  24 inch bins  09/23/2017      160.0
# 2           3       PUMPKINS    DALLAS  24 inch bins  09/30/2017      160.0
# 3           4       PUMPKINS    DALLAS  24 inch bins  09/24/2016      160.0
# 4           5       PUMPKINS    DALLAS  24 inch bins  09/24/2016      150.0
#
#    High Price Origin Color  ItemSizeR  VarietyR
# 0       225.0  TEXAS   NaN        3.0       NaN
# 1       225.0  TEXAS   NaN        3.0       NaN
# 2       225.0  TEXAS   NaN        3.0       NaN
# 3       160.0  TEXAS   NaN        5.0       1.0
# 4       150.0  TEXAS   NaN        2.0       1.0

# %%
MDWPumpkins['VarietyR']=MDWPumpkins['Variety'].apply(recode)

# %%
MDWPumpkins.drop(['Variety','Item Size'], axis=1, inplace=True)

# %%
MDWPumpkins.head()
# Out:
#    Unnamed: 0 Commodity Name City Name       Package        Date  Low Price  \
# 0           1       PUMPKINS   DETROIT  24 inch bins  09/16/2017       95.0
# 1           2       PUMPKINS   DETROIT  24 inch bins  09/16/2017       94.0
# 2           3       PUMPKINS   DETROIT  24 inch bins  09/23/2017       95.0
# 3           4       PUMPKINS   DETROIT  24 inch bins  09/23/2017       94.0
# 4           5       PUMPKINS   DETROIT          bins  09/23/2017      175.0
#
#    High Price    Origin Color  ItemSizeR  VarietyR
# 0        95.0  MICHIGAN   NaN        3.0         1
# 1        95.0  MICHIGAN   NaN        2.0         1
# 2        95.0  MICHIGAN   NaN        3.0         1
# 3        95.0  MICHIGAN   NaN        2.0         1
# 4       175.0  MICHIGAN   NaN        4.0         1

# %% [markdown]
# # Data Export

# %%
SRPumpkins.to_csv(r'C:\SRPumpkins.csv')

# %%
MDWPumpkins.to_csv(r'C:\MDWPumpkins.csv')
